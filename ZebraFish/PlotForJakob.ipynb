# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rois=np.load('/media/maria/DATA1/Documents/Downl/fish04_6dpf_amph_rois.npy')

# %%
print(rois.shape)
x_pos=rois[:,3].flatten()
print(x_pos)
for j in x_pos:
    if x_pos[j]!=0:
        print('jip')
# Out:
# (36757, 4)
# [0 0 0 ... 0 0 0]

# %%
traces=np.load('/media/maria/DATA1/Documents/Downl/fish04_6dpf_amph_traces.npy')

# %%
print(traces.shape)
# Out:
# (36757, 1800)

# %%
z_inds=np.where(rois[:,2]==5)

# %%
x_pos=rois[z_inds,0].flatten()
y_pos=rois[z_inds,1].flatten()
ints=traces[z_inds]

# %%
print(x_pos.shape)
print(y_pos.shape)
print(ints.shape)
# Out:
# (1, 2151)
# (1, 2151)
# (2151, 1800)

# %%
plt.figure(figsize=(5,5))
pc0=ints[:,100]
print(pc0)
pc0 = pc0/np.max(np.abs(ints[:,0]))
plt.scatter(x_pos, -y_pos, s=10, c=pc0, cmap='bwr', alpha = 0.25)
plt.axis('off')
plt.show()
# Out:
# [ 91.140625    93.2173913   93.5942029  ... 117.39130435 120.68115942
#  118.15942029]

# %%
import matplotlib.tri as tri
plt.tricontour(x_pos, -y_pos, ints, levels=14, linewidths=0.5, colors='k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-bc45fd562693> in <module>
#       1 import matplotlib.tri as tri
# ----> 2 plt.tricontour(x_pos, -y_pos, ints, levels=14, linewidths=0.5, colors='k')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in tricontour(*args, **kwargs)
#    2985 @docstring.copy(Axes.tricontour)
#    2986 def tricontour(*args, **kwargs):
# -> 2987     __ret = gca().tricontour(*args, **kwargs)
#    2988     if __ret._A is not None: sci(__ret)  # noqa
#    2989     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/tri/tricontour.py in tricontour(ax, *args, **kwargs)
#     268     """
#     269     kwargs['filled'] = False
# --> 270     return TriContourSet(ax, *args, **kwargs)
#     271
#     272
#
# ...
