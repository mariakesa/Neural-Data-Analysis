# %%
# Data was obtained from https://datadryad.org/stash/dataset/doi:10.5061/dryad.3q50t

# %%
import numpy as np
from PIL import Image
from skimage import io
import matplotlib.pyplot as plt

# %%
#stack_=Image.open('/media/maria/DATA1/Documents/MicroscopyImages/Boutons/2PLSM_image_stack.tif')
#stack=io.imread('/media/maria/DATA1/Documents/MicroscopyImages/Boutons/2PLSM_image_stack.tif')

# %%
#stack=np.array(stack)
#print(stack.shape)
# Out:
# (312, 1024, 1024)

# %%
#im=stack[89,:,:]
#plt.imshow(im,cmap='gray')

# %%
np.save('im.npy',im)

# %%
im=np.load('im.npy')

# %% [markdown]
# # Histogram Equalization

# %%
from skimage import exposure
p2, p98 = np.percentile(im, (2, 98))
img_rescale = exposure.rescale_intensity(im, in_range=(p2, p98))
plt.imshow(img_rescale)
