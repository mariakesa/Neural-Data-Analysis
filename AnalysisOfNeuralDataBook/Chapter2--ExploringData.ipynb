# %%
import numpy as np
from scipy.io import loadmat
import h5py
import matplotlib.pyplot as plt
import pylab

# %% [markdown]
# # Load data

# %%
#Mouse data. Data downloaded from https://figshare.com/articles/dataset/Recording_of_19_000_neurons_across_mouse_visual_cortex_during_sparse_noise_stimuli/9505250

# %%
dat=np.load('/media/maria/DATA1/Documents/data_for_suite2p/TX39_total/spks.npy')

# %%
beh=np.load('/media/maria/DATA1/Documents/data_for_suite2p/TX39_total/cam1_TX39_2019_05_31_1_proc_resampled.npy',allow_pickle=True).item()

# %%
print(beh['motSVD'].shape)
# Out:
# (500, 30766)

# %%
print(dat.shape)
# Out:
# (18795, 30766)

# %%
#Zebrafish data

# %%
hf = h5py.File('/media/maria/DATA1/Documents/ZebraFish/subject_1/TimeSeries.h5', 'r')
neural_dat=np.array(hf['CellResp'])
stim_dat=loadmat('/media/maria/DATA1/Documents/ZebraFish/subject_1/data_full.mat')['data']['stim_full'][0][0]

# %% [markdown]
# # Central Tendency

# %%
plt.hist(beh['motSVD'][0,:],bins=100,color='firebrick')
plt.title('Behavior first principal component across time')
plt.xlabel('PC value')
plt.ylabel('Number of occurences')
# Out:
# Text(0, 0.5, 'Number of occurences')

# %% [markdown]
# # Spectrogram

# %%
x = neural_dat[:,0]  # the signal
NFFT = 1024  # the length of the windowing segments
Fs = 3  # the sampling frequency

Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=1000,cmap=pylab.get_cmap('magma'))
plt.title('Spectrogram of neuron number 0')
plt.ylabel('Frequencies')
plt.xlabel('Sample points')
plt.show()

# %% [markdown]
# # Log scale

# %%
plt.hist(np.log(beh['motSVD'][0,:]),bins=100,color='firebrick')
plt.title('Behavior first principal component across time on log scale')
plt.xlabel('Log PC value')
plt.ylabel('Number of occurences')
# Out:
# /home/maria/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# Text(0, 0.5, 'Number of occurences')

# %%
plt.hist(np.log(dat[:,100].flatten()),bins=1000,color='darkgoldenrod')
plt.title('log transform of 100 neurons')
plt.xlabel('log neural activity values')
plt.xlim(0,100)
plt.ylabel('Number of occurrences')
# Out:
# /home/maria/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b9a1ccda2064> in <module>
# ----> 1 plt.hist(np.log(dat[:,100].flatten()),bins=1000,color='darkgoldenrod')
#       2 plt.title('log transform of 100 neurons')
#       3 plt.xlabel('log neural activity values')
#       4 plt.xlim(0,100)
#       5 plt.ylabel('Number of occurrences')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6773             # this will automatically overwrite bins,
#    6774             # so that each histogram uses the same bins
# -> 6775             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6776             m = m.astype(float)  # causes problems later if it's an int
#    6777             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     424             raise ValueError('`bins` must be positive, when an integer')
#     425
# --> 426         first_edge, last_edge = _get_outer_edges(a, range)
#     427
#     428     elif np.ndim(bins) == 1:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     314         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     315             raise ValueError(
# --> 316                 "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#     317     elif a.size == 0:
#     318         # handle empty arrays. Can't determine range, so use 0-1.
#
# ValueError: supplied range of [-inf, 7.963677883148193] is not finite
